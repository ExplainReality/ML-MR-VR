# %%
# %pip install icrawler
# %pip install icrawler Pillow imagehash
# %pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from icrawler.builtin import GoogleImageCrawler
import os

keyword = 'broken iphone'
folder = r'D:\ML-MR-VR\data\ewaste_images\other_phone'

os.makedirs(folder, exist_ok=True)

print(f"🔍 Searching for '{keyword}' images...")

google_crawler = GoogleImageCrawler(storage={'root_dir': folder})
google_crawler.crawl(
    keyword=keyword,
    max_num=1000,
    filters={'license': 'commercial,modify', 'type': 'photo'}
)
print(f"✅ Done! Downloaded images are in: {folder}")
# Out:
# 2025-04-10 13:10:45,289 - INFO - icrawler.crawler - start crawling...
# 2025-04-10 13:10:45,297 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2025-04-10 13:10:45,305 - INFO - icrawler.crawler - starting 1 parser threads...
# 2025-04-10 13:10:45,314 - INFO - icrawler.crawler - starting 1 downloader threads...
# 🔍 Searching for 'broken iphone' images...
# 2025-04-10 13:10:46,885 - INFO - parser - parsing result page https://www.google.com/search?q=broken+iphone&ijn=0&start=0&tbs=sur%3Afmc%2Citp%3Aphoto&tbm=isch
# 2025-04-10 13:10:47,562 - INFO - downloader - skip downloading file 000001.jpg
# 2025-04-10 13:10:47,576 - INFO - downloader - skip downloading file 000002.jpg
# 2025-04-10 13:10:47,579 - INFO - downloader - skip downloading file 000003.jpg
# 2025-04-10 13:10:47,582 - INFO - downloader - skip downloading file 000004.jpg
# 2025-04-10 13:10:47,623 - INFO - downloader - skip downloading file 000005.jpg
# ...

# %%
from icrawler.builtin import GoogleImageCrawler
import os

keyword = 'cylinder battery'
folder = r'D:\ML-MR-VR\data\ewaste_images\battery_cylinder'

os.makedirs(folder, exist_ok=True)

print(f"🔍 Searching for '{keyword}' images...")

google_crawler = GoogleImageCrawler(storage={'root_dir': folder})
google_crawler.crawl(
    keyword=keyword,
    max_num=300,
    filters={'license': 'commercial,modify', 'type': 'photo'},
)
print(f"✅ Done! Downloaded images are in: {folder}")
# Out:
# 🔍 Searching for 'cylinder battery' images...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 12
#       9 print(f"🔍 Searching for '{keyword}' images...")
#      11 google_crawler = GoogleImageCrawler(storage={'root_dir': folder})
# ---> 12 google_crawler.crawl(
#      13     keyword=keyword,
#      14     max_num=300,
#      15     filters={'license': 'commercial,modify', 'type': 'photo'},
#      16     delay=1
#      17 )
#      18 print(f"✅ Done! Downloaded images are in: {folder}")
#
# TypeError: GoogleImageCrawler.crawl() got an unexpected keyword argument 'delay'

# %%
# %pip install scrapy
# Out:
# ...
#
# ...

# %%
from icrawler.builtin import GoogleImageCrawler
import os

keyword = 'samsung s10 tel battery'
folder = r'D:\ML-MR-VR\data\ewaste_images\battery_samsung_s'

print(f"🔍 Searching for '{keyword}' images...")

google_crawler = GoogleImageCrawler(
    storage={'root_dir': folder},
    downloader_threads=1
)

google_crawler.downloader.min_sleep = 2
google_crawler.downloader.max_sleep = 3 

google_crawler.crawl(
    keyword=keyword,
    max_num=300,
    # filters={'license': 'commercial,modify', 'type': 'photo'},
)

print(f"✅ Done! Downloaded images are in: {folder}")
# Out:
# 2025-04-10 17:25:11,240 - INFO - icrawler.crawler - start crawling...
# 2025-04-10 17:25:11,240 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2025-04-10 17:25:11,248 - DEBUG - feeder - thread feeder-001 started
# 2025-04-10 17:25:11,248 - DEBUG - feeder - put url to url_queue: https://www.google.com/search?q=samsung+s10+tel+battery&ijn=0&start=0&tbs=&tbm=isch
# 2025-04-10 17:25:11,264 - INFO - icrawler.crawler - starting 1 parser threads...
# 2025-04-10 17:25:11,268 - DEBUG - feeder - put url to url_queue: https://www.google.com/search?q=samsung+s10+tel+battery&ijn=1&start=100&tbs=&tbm=isch
# 2025-04-10 17:25:11,273 - DEBUG - parser - thread parser-001 started
# 2025-04-10 17:25:11,274 - DEBUG - feeder - put url to url_queue: https://www.google.com/search?q=samsung+s10+tel+battery&ijn=2&start=200&tbs=&tbm=isch
# 2025-04-10 17:25:11,282 - DEBUG - parser - start fetching page https://www.google.com/search?q=samsung+s10+tel+battery&ijn=0&start=0&tbs=&tbm=isch
# ...

# %%
import os
import zipfile

# Unzip the ZIP file
zip_path = r'D:\ML-MR-VR\data\ewaste_images\battery_phone.zip'
extract_folder = r'D:\ML-MR-VR\data\ewaste_images\battery_phone'

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_folder)

# Iterate through all files and rename jpg files
counter = 1
for root, dirs, files in os.walk(extract_folder):
    for file in files:
        if file.lower().endswith('.jpg'):
            # Construct new file name
            new_name = f"phone_battery_{counter}.jpg"
            old_file_path = os.path.join(root, file)
            new_file_path = os.path.join(root, new_name)
            
            # Rename the file
            os.rename(old_file_path, new_file_path)
            counter += 1

print("Renaming complete!")
# Out:
# Renaming complete!
